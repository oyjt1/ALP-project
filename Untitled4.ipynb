# %% [markdown]
# <a href="https://colab.research.google.com/github/oyjt1/ALP-project/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
AL=input()
if AL=="A":
    print("1")
elif AL=="B":
    print("2")
elif AL=="C":
    print("3")
elif AL=="D":
    print("4")
elif AL=="E":
    print("5")
elif AL=="F":
    print("6")
elif AL=="G":
    print("7")
elif AL=="H":
    print("8")
elif AL=="I":
    print("9")
elif AL=="J":
    print("10")
elif AL=="K":
    print("11")
elif AL=="L":
    print("12")
elif AL=="M":
    print("13")
elif AL=="N":
    print("14")
elif AL=="O":
    print("15")
elif AL=="P":
    print("16")
elif  AL=="Q":
    print("17")
elif AL=="R":
    print("18")
elif AL=="S":
    print("19")
elif AL=="T":
    print("20")
elif AL=="U":
    print("21")
elif AL=="V":
    print("22")
elif AL=="W":
    print("23")
elif AL=="X":
    print("24")
elif AL=="Y":
    print("25")
elif AL=="Z":
    print("26")
BL=input()
if BL=="A":
    print("1")
elif BL=="B":
    print("2")
elif BL=="C":
    print("3")
elif BL=="D":
    print("4")
elif BL=="E":
    print("5")
elif BL=="F":
    print("6")
elif BL=="G":
    print("7")
elif BL=="H":
    print("8")
elif BL=="I":
    print("9")
elif BL=="J":
    print("10")
elif BL=="K":
    print("11")
elif BL=="L":
    print("12")
elif BL=="M":
    print("13")
elif BL=="N":
    print("14")
elif BL=="O":
    print("15")
elif BL=="P":
    print("16")
elif  BL=="Q":
    print("17")
elif BL=="R":
    print("18")
elif BL=="S":
    print("19")
elif BL=="T":
    print("20")
elif BL=="U":
    print("21")
elif BL=="V":
    print("22")
elif BL=="W":
    print("23")
elif BL=="X":
    print("24")
elif BL=="Y":
    print("25")
elif BL=="Z":
    print("26")
CL=input()
if CL=="A":
    print("1")
elif CL=="B":
    print("2")
elif CL=="C":
    print("3")
elif CL=="D":
    print("4")
elif CL=="E":
    print("5")
elif CL=="F":
    print("6")
elif CL=="G":
    print("7")
elif CL=="H":
    print("8")
elif CL=="I":
    print("9")
elif CL=="J":
    print("10")
elif CL=="K":
    print("11")
elif CL=="L":
    print("12")
elif CL=="M":
    print("13")
elif CL=="N":
    print("14")
elif CL=="O":
    print("15")
elif CL=="P":
    print("16")
elif  CL=="Q":
    print("17")
elif CL=="R":
    print("18")
elif CL=="S":
    print("19")
elif CL=="T":
    print("20")
elif CL=="U":
    print("21")
elif CL=="V":
    print("22")
elif CL=="W":
    print("23")
elif CL=="X":
    print("24")
elif CL=="Y":
    print("25")
elif CL=="Z":
    print("26")
DL=input()
if   DL=="A":
    print("1")
elif DL=="B":
    print("2")
elif DL=="C":
    print("3")
elif DL=="D":
    print("4")
elif DL=="E":
    print("5")
elif DL=="F":
    print("6")
elif DL=="G":
    print("7")
elif DL=="H":
    print("8")
elif DL=="I":
    print("9")
elif DL=="J":
    print("10")
elif DL=="K":
    print("11")
elif DL=="L":
    print("12")
elif DL=="M":
    print("13")
elif DL=="N":
    print("14")
elif DL=="O":
    print("15")
elif DL=="P":
    print("16")
elif DL=="Q":
    print("17")
elif DL=="R":
    print("18")
elif DL=="S":
    print("19")
elif DL=="T":
    print("20")
elif DL=="U":
    print("21")
elif DL=="V":
    print("22")
elif DL=="W":
    print("23")
elif DL=="X":
    print("24")
elif DL=="Y":
    print("25")
elif DL=="Z":
    print("26")
# Out:
# 1
# 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-7a85ee4cc935> in <cell line: 107>()
#     105 elif BL=="Z":
#     106     print("26")
# --> 107 CL=input()
#     108 if CL=="A":
#     109     print("1")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
4
Q1=int(input("enter key"))
Q2=int(input("enter key"))
Q3=int(input("enter key"))
Q4=int(input("enter key"))
A1=int(input("enter text: "))
A2=int(input("enter text: "))
A3=int(input("enter text: "))
A4=int(input("enter text: "))
N1=(int(Q1*A1+Q3*A2)%26)
N2=(int((Q2*A1+Q4*A2)%26))
N3= (int(Q1*A3+Q3*A4)%26)
N4= (int(Q2*A3+Q4*A4)%26)
print(N1)
print(N2)
print(N3)
print(N4)
# Out:
# enter key1
# enter key2
# enter key3
# enter key4
# enter text: 1
# enter text: 2
# enter text: 3
# enter text: 4
# 7
# 10
# 15
# 22
